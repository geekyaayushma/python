# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# **Class and Object :**
#
# A **class** is a blueprint or a template for creating objects. It defines the structure and behavior that all objects of that class will possess.
#
# An **object** is an instance of a class. It is a concrete entity created based on the blueprint provided by the class.

# %%
class Student:
    name = "Aayushma Mahat",
    roll_no = 22

# creating object (instance)

s1 = Student()
s2 = Student()
print(s1)
print(s1.name)
print(s2.name)

# %%
class Car:
    color = "Blue",
    brand = "Mercedes"

car1 = Car()
print(car1.color)
print(car1.brand)

# %% [markdown]
# **__init__function / Constructor**
#
#
# All classes have a function called __init__(), which is always executed when the object is being initied.

# %%
#creating class

class Car:
    color = "Blue",

    #defult_constructors    
    def __init__():
        pass

    #parametarized constructor 
    def __init__(self , fullBrand , id):
        self.brand = fullBrand
        self.id = id
        print("adding new car in database",self.brand)

#creating object

car1 = Car("honda" , 1)
print(car1.brand , car1.id)

car2 = Car("BYD" , 2)
print(car2.brand , car2.id)
# Out:
# adding new car in database honda
# honda 1
# adding new car in database BYD
# BYD 2

# %% [markdown]
# The **self parameter** is a reference to the current instance of the class, and is used to acess variables that belongs to the class.

# %% [markdown]
# **Class and instance Attributes:**

# %%
class Student:
    # Class attribute - shared by all instances
    school = "ABC High School"
    name = "anonymos" # class atr
    
    def __init__(self, name = "Aayu", roll_no = "1"):
        # Object attributes - unique to each instance
        self.name = name #obj attr > class attr 
        self.roll_no = roll_no
        print(f"Student {self.name} added to database")

# Creating objects with default values
s1 = Student()

# Creating objects with custom values
s2 = Student("Ram Sharma", 25)
s3 = Student("Sita Poudel", 30)

print(f"s1 name: {s1.name}")
print(f"s2 name: {s2.name}")
print(f"s3 name: {s3.name}")

print(f"school (class attr): {Student.school}")
# Out:
# Student Aayu added to database
# Student Ram Sharma added to database
# Student Sita Poudel added to database
# s1 name: Aayu
# s2 name: Ram Sharma
# s3 name: Sita Poudel
# school (class attr): ABC High School

# %% [markdown]
# **Methods:**
#
# Methods are function that belong to objects.
# There are three methods:
# * static methods
# * class methods
# * instance methods

# %%
class Student:
    def __init__(self, name , marks):
        self.name = name
        self.mark = marks

    def hello(self):
        print("Konichiwa" , self.name)

    def get_marks(self):
        return self.mark


s1 = Student("Nisha" ,100)

s1.hello()
print(s1.get_marks())
# Out:
# Konichiwa Nisha
# 100

# %% [markdown]
# **Static Methods :**
#
# Methods that don't use the self parameter (works at class level).
#
# syntax:
# @ static method
# ..... #decorator
#
# Decorator allows us to wrap another function in order to extend the behaviour of the wrapped function, without premanently modifying it.

# %%
class Student:
    def __init__(self, name ):
        self.name = name

    @staticmethod #decorator
    def hello():
        print("Konichiwa")

s1 = Student("Nisha")

s1.hello()
# Out:
# Konichiwa

# %% [markdown]
# **Class Method**
#
# A class method - to the class anad receives the class as an implicit first argument.
# Note - static method can't access or modify class state and generally for utility.
# syntax: @classmethod #decorator

# %%
class Person:
    name = "anomymous"

    def changeName(self,name):
        #this
        self.__class__.name = name
        #or this Person.name = name 

p1 = Person()
p1.changeName("Aayushma")
print(p1.name)
print(Person.name)
# Out:
# Aayushma
# Aayushma

# %%
class Person:
    name = "anomymous"
    
    @classmethod
    def changeName(cls,name):
        cls.name = name
 

p1 = Person()
p1.changeName("Aayushma")
print(p1.name)
# Out:
# Aayushma

# %% [markdown]
# **Property:**
#
# We use @propery decorator on any method in the class to use the method as a property.

# %%
class Student:
    def __init__(self,phy,chem,math):
        self.phy= phy
        self.chem = chem
        self.math = math
        
    @property
    def percentage(self):
        return str((self.phy+self.chem+self.math)/3)+"%"
        
stu1 = Student(98,44,55)
print(stu1.percentage)

stu1.phy =86
print(stu1.percentage)
# Out:
# 65.66666666666667%
# 61.666666666666664%

# %% [markdown]
# # Practice

# %%
# Create student class that takes name & marks of 3 subjects as arguments in constructor. Then create a method to print the average.

class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def print_average(self):
        total = 0
        for mark in self.marks:  
            total += mark
        average = total / len(self.marks)
        print(f"{self.name}'s average marks: {average:.2f}")

student1 = Student("Alice", [85, 92, 78])
student2 = Student("Bob", [76, 88, 91])

student1.print_average()
student2.print_average()
# Out:
# Alice's average marks: 85.00
# Bob's average marks: 85.00

# %% [markdown]
# **Abstraction**
#
# Hiding the implementation details of a class and only showing the essential features to the user.
#
# **Encapsulation**
#
# Wrapping data and functions into a single unit(object).

# %%
class Car:  #encapsulation
    def __init__(self):
        self.acc = False
        self.brk = False
        self.clutch = False
        
    def start(self):
       self.clutch = True
       self.acc = True
       print("Car started..")

car1 = Car()
car1.start() #abstraction
# Out:
# Car started..

# %% [markdown]
# # Practice

# %%
# Create Account class with 2 attributes -balance and account no. Create methods for debit, credit and printing the balance.

class Account:
    def __init__(self, balance, account_no):
        self.balance = balance
        self.account_no = account_no

    def debit(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Debited {amount}. Remaining balance: {self.balance}")
        else:
            print("Insufficient balance!")

    def credit(self, amount):
        self.balance += amount
        print(f"Credited {amount}. New balance: {self.balance}")

    def print_balance(self):
        print(f"Account {self.account_no} balance: {self.balance}")

Acc1 = Account(10000, 323289328430)

Acc1.debit(2000)       
Acc1.credit(5000)      
Acc1.print_balance()
# Out:
# Debited 2000. Remaining balance: 8000
# Credited 5000. New balance: 13000
# Account 323289328430 balance: 13000

# %% [markdown]
# **del keyword**
#
# Used to delete object propertied or object itself.

# %%
class Student:
    def __init__(self,name):
        self.name = name

s1 = Student("shuush")
print(s1)
del s1 # or to delete attribute in object del s1.name
#print(s1) this will show error

# %% [markdown]
# **Private(like)** attributes and methods:
#
# Pr'ivate attibutes and methods are meant to be used only within the class and are not accessible for outside the class
# To define a private method prefix the member name with the double underscore “__”.

# %%
class Person:
    __name = "anonymous"

    def __hello(self):
        print("hello person" , self.__name)

    def welcome(self):
        self.__hello()

p1 = Person()

print(p1.welcome())
# Out:
# hello person anonymous
# None

# %%
class Account:
    def __init__(self , account_no , account_pw):
        self.acc_no = account_no
        self.__acc_pw = account_pw

    def reset_pass(self):
        print(self.__acc_pw)

user1 = Account(12323232, "8943urj")

print(user1.acc_no)
print(user1.reset_pass())
# print(user1.__acc_pw) cannot acess outside the class
# Out:
# 12323232
# 8943urj
# None

# %% [markdown]
# **Inheritance:**
#
# When one class(child/derived) derives the properties and method of another class(parent/base).
#
# Types of inheritance :
# * Single Inheritance
# * Multi-level Inheritance
# * Multiple Inheritance

# %%
#Single Inheritance
class Car:
    
    @staticmethod
    def start():
        print("car start")
        
    @staticmethod
    def stop():
        print("car stop")

class ToyotaCar(Car):
    def __init__(self,name):
        self.name = name

car1 = ToyotaCar("Fortuner")
car2 = ToyotaCar("Pirus")

print(car1.start())
# Out:
# car start
# None

# %%
#Multi-level Inheritance

class Car:

    @staticmethod
    def start():
        print("Start...")

    @staticmethod
    def stop():
        print("Stop...")

class Toyota(Car):
    def __init__(self,brand):
        self.brand = brand

class Fortuner(Toyota):
    def __init__(self,type):
        self.type = type

car1 = Fortuner("Diseal")
car1.start()
# Out:
# Start...

# %%
 #Multiple Inheritance

class A:
    varA = "Welcome to class A"

class B:
    varB = "Welcome to class B"

class C(A,B):
    varC = "Welcome to class C"

abc1 = C()
print(abc1.varA , abc1.varB , abc1.varC)
# Out:
# Welcome to class A Welcome to class B Welcome to class C

# %% [markdown]
# **Super Method:**
#
# super() method is used to access methods of the parent class.

# %%
#Multi-level Inheritance

class Car:
    def __init__(self,type):
        self.type = type 
        
    @staticmethod         
    def start():
        print("Start...")

    @staticmethod
    def stop():
        print("Stop...")

class Toyota(Car):
    def __init__(self,name,type):
        self.name = name
        super().__init__(type)
        super().start()

car1 = Toyota("Fortuner","electric")
print(car1.type)
# Out:
# Start...
# electric

# %% [markdown]
# **Polymorphism** : Operator Overloading
#
# When the same operator is allowed to have different meaning according to the context.
#
# **Operators and Dunder functions**
#
#
# * a+b  addition a.__add__(b)
# * a-b subtraction a.__sub__(b)
# * a*b multiplication a.__mul____(b)
# * a/b division a.__truediv____(b)
# * a%b addition a.__mod____(b)

# %%
# Implicit overloading

print(2+3) # used to add two numbers
print(type(1))

print("Programming" + "language") # used to add two string - concatenate
print(type("programming"))

print ([23,4,43] + [2,4,5]) #merge two list
print(type([23,4,43]))
# Out:
# 5
# <class 'int'>
# Programminglanguage
# <class 'str'>
# [23, 4, 43, 2, 4, 5]
# <class 'list'>

# %%
class Complex:
    def __init__(self,real,img):
        self.real = real
        self.img = img

    def showNumber(self):
        print(self.real, "i+" , self.img , "j")

    def __add__(self,num2):
        newReal = self.real + num2.real
        newImg = self.img + num2.img
        return Complex (newReal, newImg)

num1 = Complex(1,3)
num1.showNumber()

num2 = Complex(2,20)
num2.showNumber()

num3 = num1+num2
num3.showNumber()
# Out:
# 1 i+ 3 j
# 2 i+ 20 j
# 3 i+ 23 j

# %%
class Complex:
    def __init__(self,real,img):
        self.real = real
        self.img = img

    def showNumber(self):
        print(self.real, "i+" , self.img , "j")

    def __sub__(self,num2):
        newReal = self.real - num2.real
        newImg = self.img - num2.img
        return Complex (newReal, newImg)

num1 = Complex(1,3)
num1.showNumber()

num2 = Complex(2,20)
num2.showNumber()

num3 = num1-num2
num3.showNumber()
# Out:
# 1 i+ 3 j
# 2 i+ 20 j
# -1 i+ -17 j

# %% [markdown]
# # Practice

# %%
# Define a Circle class to create with radius r using the constructor. Define an Area() method of the class which calculates the area of the circle. Define a Perimeter() method of the class which allows you to calculate the perimeter of the circle.

class Circle():
    def __init__(self,radius):
        self.radius = radius 
        
    @property
    def Area(self):
        return  3.14159265359 * self.radius ** 2

    @property
    def Perimeter(self):
        return  2 * 3.14159265359 * self.radius

circle1 = Circle(5)
print(f"The area of circle1 is  {circle1.Area}")
print(f"The perimeter of circle1 is  {circle1.Perimeter}")

circle1.radius = 45
print(f"The new area of circle1 is  {circle1.Area}")
print(f"The new perimeter of circle1 is  {circle1.Perimeter}")
# Out:
# The area of circle1 is  78.53981633975
# The perimeter of circle1 is  31.4159265359
# The new area of circle1 is  6361.72512351975
# The new perimeter of circle1 is  282.74333882310003

# %%
# Define a Employee class with attributes role, department & salary .This class also has a showDetaila() method  . Create an Engineer class that inherits properties from Employee and has additional attributes : name & age.

class Employee:
    def __init__(self, role, department, salary):
        self.role = role
        self.department = department
        self.salary = salary

    def showDetails(self):
        print("role =", self.role)
        print("dept =", self.department)
        print("salary =", self.salary)


class Engineer(Employee):
    def __init__(self, name, age):
        self.name = name
        self.age = age
        # call parent constructor properly
        super().__init__("Engineer", "IT", 75000)


emp1 = Engineer("Ram", 21)
emp1.showDetails()
# Out:
# role = Engineer
# dept = IT
# salary = 75000

# %%
# Create a class called Order which stores item and its price. Use Dunder function__gt__() to convey that: order1>order2 if price of order1 > price of order2

class Order:
    def __init__(self,item,price):
        self.item = item
        self.price = price

    def __gt__(self,ord2):
        return self.price> ord2.price

ord1 = Order ("chips" ,20)
ord2 = Order ("tea" , 15)

print(ord1,ord2)
# Out:
# <__main__.Order object at 0x7f4e1ae49cd0> <__main__.Order object at 0x7f4e1e31f890>
